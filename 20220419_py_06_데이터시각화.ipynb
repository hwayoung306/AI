# %% [markdown]
# <a href="https://colab.research.google.com/github/hwayoung306/AI/blob/main/20220419_py_06_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%8B%9C%EA%B0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 구글드라이브 연동

# %%
# 구글드라이브 연동
from google.colab import drive
drive.mount('/gdrive', force_remount=True)

# 구글 드라이브 파일 확인
# !ls '/gdrive/My Drive/temp/'

# 반복되는 드라이브 경로 변수화
drive_path = '/gdrive/My Drive/temp/'
# Out:
# Mounted at /gdrive
#  매수종목1.txt			        sample2.pdf
# '2. 영화평점, 날짜별 영화평점 시각화'   sample.docx
#  매수종목2.txt			        sample_merge.pdf
#  auto-mpg.csv			        sample.xlsx
#  bmi_500.csv			        score.csv
#  매수종목.csv			        seoul.html
#  data_studentlist_en.csv	       'stock price.xlsx'
# 'demo (1).docx'			       'stock valuation.xlsx'
#  demo.docx			        test.db.db
#  example.docx			        test.txt
#  height_weight.txt		        Titanic배포용
#  hello_world.xlsx		        titanic_test.csv
#  HelloWorld.xlsx		        titanic_train.csv
# 'little-char (1).png'		        titanic.xls
#  little-char.png		        Traffic_Accident_2017.csv
#  population_number.csv		        train.csv
#  ram_price.csv			        user_id_mean.csv
#  ratings_small.txt		        wine.csv
# 'sample1 (1).pdf'		        주가데이터.xlsx
#  sample1.pdf			        남북한발전전력량.xlsx
# 'sample (1).xlsx'

# %% [markdown]
# # 데이터 시각화
#
# - 광범위하게 분산된 방대한 양의 자료를 한눈에 볼 수 있도록 도표나 차트 등으로 정리하는 것
# - 시각화를 통해 데이터의 특징을 쉽게 파악
# - 분석 결과를 상대방에게 효과적으로 전달 가능

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import DataFrame, Series
from numpy.random import randn

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Matplotlib 기초

# %%
fig = plt.figure()
fig.clear() # 계속 누적되기 때문에 지우는 것
ex1 = fig.add_subplot(2, 2, 1)
ex2 = fig.add_subplot(2, 2, 2)
ex3 = fig.add_subplot(2, 2, 3)

fig.show()

# %%
ex1.plot([2,3,4]) # 선을 긋는 방법
fig

# %%
y = [2,4,6] # y값만 대입하는 것 x는 대입하지 않으면 마음대로 됨
plt.plot(y) # 선 그래프
plt.show()

# %%
# x, y값을 지정하는 방법
x = [1,2,3,4,5,6,7]
y = [2,4,6,4,5,6,4]
plt.plot(x,y)
plt.show()

# %% [markdown]
# Lime style 선의 스타일을 바꿀 수 있음
#
# |Character| Description|
# |---|---|
# |‘ - ’| Solid line style|
# |‘ -- ’| Dashed line style|
# |‘ -. ’| Dash-dot lint style|
# |‘ : ’| Dotted line style|

# %%
plt.plot(x,y, ls='--')
plt.show()

# %% [markdown]
# Marker 데이터에 점을 찍도록 하는 것
#
# |Character| Description |Character| Description|
# |---|---|---|---|
# | ‘ . ’| Point marker |‘ 1 ’| Tri_down marker |
# |‘ o ’| Circle marker |‘ 2 ’| Tri_up marker |
# |‘ v ’| Triangle_down marker |‘ 3 ’| Tri_left marker |
# |‘ ^ ’| Triangle_up marker |‘ 4 ’| Tri_right marker |
# |‘ < ‘| Triangle_left marker |‘ * ‘| Star marker |
# |‘ > ‘| Triangle_right marker |‘ h ‘, ‘ H ’| Hexagon1,2 marker |
# |‘ s ‘| Square marker |‘ + ‘| Plus marker |
# |‘ p ‘| Pentagon marker |‘ D ‘| Diamond marker |
# |‘ | ‘| Vline marker |‘ _ ‘| Hline marker|

# %%
plt.plot(x, y, marker='p', ls='-')
plt.show()

# %% [markdown]
# Line color
#
# |Character |Color| Character| Color|
# |---|---|---|---|
# |‘ b ’| Blue |‘ m ‘| Magenta|
# |‘ g ’| Green |‘ y ‘| yellow|
# |‘ r ‘| Red |‘ k ‘| Black|
# |‘ c ‘| cyan |‘ w ‘| white|

# %%
plt.plot(x,y,c ='g')
plt.show()

# %% [markdown]
# Style option
#
# |스타일옵션종류| 설명| 약자|
# |---|---|---|
# |color| 선 색깔| c|
# | linewidth| 선 굵기| lw|
# | linestyle| 선 스타일| ls|
# | marker| 마커 종류| |
# | markersize| 마커 크기| ms|
# | markeredgecolor| 마커 선 색깔| mec|
# | markeredgewidth| 마커 선 굵기| mew|
# | markerfacecolor| 마커 내부 색깔| mfc|

# %%
plt.plot(x, y, lw ='5', c ='y', marker='o', ms ='10', mec='k',mfc='r')
plt.show()

# %% [markdown]
# #### Matplotlib 연습 01
#
# ```
# x = np.arange(7)
# y = [1,4,5,8,9,5,3]
# ```
# 꺽은 선 그래프
#
# A

# %%
# 선 그래프 그리기 -> 점선, 점모양 마커는, 마커엣지색은 그린, 마커엣지두께는 1, 마커컬러 그린, 마커사이즈는 5
x = np.arange(7)
y = [1,4,5,8,9,5,3]

plt.plot(x,y, ls='--', marker='o', mfc='g', mew='1', mec ='g',ms ='5')

# %% [markdown]
# #### 차트 옵션
#
# |plot| 옵션 정의|
# |---|---|
# |xlim, ylim| x 축 범위, y축 범위|
# |grid| 격자눈금|
# |legend| 범례|
# |xlabel, ylabel| x축 타이틀, y축 타이틀|
# |title| 그래프 제목|
# |xticks, yticks |x축 눈금 조정, y축 눈금 조정|

# %% [markdown]
# #### 그림 범위 지정
#
# - 플롯 그림을 보면 몇몇 점들은 그림의 범위 경계선에 있어서 잘 보이지 않는 경우
# - 그림의 범위를 수동으로 지정하려면 xlim 명령과 ylim 명령을 사용
# - 그림의 범위가 되는 x축, y축의 최소값과 최대값을 지정

# %%
plt.xlim(-2, 8)
plt.ylim(-5, 10)
plt.plot(x,y,ls='--', marker='o', mec = 'g', mew ='1', mfc = 'g', ms ='5')
plt.show()

# %% [markdown]
# #### 틱(tick)
#
# 플롯이나 차트에서 축상의 위치 표시 지점
#
# - 틱 라벨(tick label) : 틱에 써진 숫자 혹은 글자
# - 틱의 위치나 틱 라벨은 Matplotlib가 자동으로 정해주지만  수동으로 설정시 xticks , yticks 명령을 사용

# %%
plt.xticks( [0, 3, 6] )
plt.yticks( [1, 5, 8] )
plt.grid() # 그리드는 틱에 맞춰서 나타남
plt.plot(x,y,ls='--', marker='o', mec = 'g', mew ='1', mfc = 'g', ms ='5')
plt.show()

# %% [markdown]
# #### 여러 개 플롯

# %%
y1 = [1, 2, 3, 4]
y2 = [2, 4, 6, 8]
y3 = [3, 6, 9, 12]
plt.plot(y1)
plt.plot(y2)
plt.plot(y3)

# plt.xlim(0, 12)
# plt.xlim(0, 12)
plt.show()

# %% [markdown]
# #### 범례

# %%
plt.plot(y1, label='y1')
plt.plot(y2, label='y2')
plt.plot(y3, label='y3')
plt.legend() # 범례를 표시하는 것
plt.show()

# %% [markdown]
# #### 차트 한글

# %%
# Windows
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
from matplotlib import rc
rc('font', family='Malgun Gothic')

# %% [markdown]
#  코렙에서 한글 사용

# %%
# !apt -qq -y install fonts-nanum
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.

# %% [markdown]
# #### Matplotlib 연습 02-1
#
# 공공데이터 : 전국사망교통사고 2017을 시각화

# %%
# 요일별 사망교통사고 시각화
import pandas as pd
df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc=kr')
df.T
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4065 entries, 0 to 4064
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   발생년           4065 non-null   int64
#  1   발생년월일시        4065 non-null   int64
#  2   발생분           4065 non-null   int64
#  3   주야            4065 non-null   object
#  4   요일            4065 non-null   object
#  5   사망자수          4065 non-null   int64
#  6   사상자수          4065 non-null   int64
#  7   중상자수          4065 non-null   int64
#  8   경상자수          4065 non-null   int64
#  9   부상신고자수        4065 non-null   int64
#  10  발생지시도         4065 non-null   object
#  11  발생지시군구        4065 non-null   object
#  12  사고유형_대분류      4065 non-null   object
#  13  사고유형_중분류      4065 non-null   object
#  14  사고유형          4065 non-null   object
#  15  법규위반_대분류      4065 non-null   object
#  16  법규위반          4065 non-null   object
#  17  도로형태_대분류      4065 non-null   object
# ...

# %%
# 요일별 사고 건수 count
y = df['요일'].value_counts()
plt.plot(y)
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53664 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
x = ['월','화','수','목','금','토','일']
plt.plot(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
y = y[ ['월', '화', '수', '목', '금', '토', '일'] ]
plt.ylim(450, 650)
plt.plot(y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44552 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
x = range(7)
plt.xticks(x, ['월', '화', '수', '목', '금', '토', '일'])
plt.bar(x, y)
plt.ylim(450, 650)
plt.xlabel('요일')
plt.ylabel('사고건수')
plt.title('요일별 교통사고건수')
plt.show()
# Out:
# findfont: Font family ['NanumBarunGothic'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 53685 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #### Matplotlib 연습 02-2
#
# 공공데이터 : 차 vs 차 교통사고 다발 발생지 시도 시각화

# %%
df.head().T
df['발생지시도'].unique()
df['사고유형_대분류'].unique()
# Out:
# array(['차대차', '차대사람', '차량단독', '철길건널목'], dtype=object)

# %%
t = df[ ['발생지시도', '사고유형_대분류'] ]
t = t[ t['사고유형_대분류'] == '차대차']
t = t['발생지시도'].value_counts()

x = t.index
y = t.values

plt.bar(x,y)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 45224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48513 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# #### 카테고리 (범주형)

# %%
ages = [0, 2, 10, 21, 23, 37, 31, 61, 20, 41, 32, 100]
bins = [0, 15, 25, 35, 60, 99]
labels = ["미성년자", "청년", "중년", "장년", "노년"]

# %% [markdown]
# #### Matplotlib 연습 02-2
#
# 교통사고 다발 시간대 시각화
#
# > 0-2, 3-5, 6-8, 9-11, 12-14, 15-17, 18-20, 21-23시 8개의 구간으로 나누어서 진행

# %%
df.head().T
# Out:
#                         0            1            2            3            4
# 발생년                  2017         2017         2017         2017         2017
# 발생년월일시         2017010101   2017010102   2017010102   2017010102   2017010104
# 발생분                    15           28           43           22           37
# 주야                     야간           야간           야간           야간           야간
# 요일                      일            일            일            일            일
# 사망자수                    1            1            1            1            1
# 사상자수                    2            1            2            1            1
# 중상자수                    1            0            0            0            0
# 경상자수                    0            0            1            0            0
# 부상신고자수                  0            0            0            0            0
# 발생지시도                  전남           서울           충남           충남           서울
# ...

# %%
time_df = df['발생년월일시'] % 100
t = time_df.value_counts().sort_index()

t
# Out:
# 0     167
# 1     128
# 2     126
# 3     105
# 4     159
# 5     180
# 6     196
# 7     130
# 8     140
# 9     171
# 10    173
# 11    182
# 12    141
# 13    158
# 14    173
# 15    182
# 16    170
# 17    198
# 18    271
# 19    230
# 20    191
# 21    169
# 22    151
# 23    174
# Name: 발생년월일시, dtype: int64

# %%
x = time_df
bins = [-1, 2, 5, 8, 11, 14, 17, 20, 24]
labels = ['0-2', '3-5', '6-8', '9-11', '12-14', '15-17', '18-20', '21-23']

cuts = pd.cut(x, bins, labels=labels)
cuts
# Out:
# 0         0-2
# 1         0-2
# 2         0-2
# 3         0-2
# 4         3-5
#         ...
# 4060    18-20
# 4061    18-20
# 4062    18-20
# 4063    18-20
# 4064    21-23
# Name: 발생년월일시, Length: 4065, dtype: category
# Categories (8, object): ['0-2' < '3-5' < '6-8' < '9-11' < '12-14' < '15-17' < '18-20' < '21-23']

# %%
rs = cuts.value_counts().sort_index()
rs
# Out:
# 0-2      421
# 3-5      444
# 6-8      466
# 9-11     526
# 12-14    472
# 15-17    550
# 18-20    692
# 21-23    494
# Name: 발생년월일시, dtype: int64

# %%
x = rs.index
y = rs.values
plt.bar(x, y)
plt.ylim(300, 700)
plt.show()

# %%
plt.pie(rs, labels=labels, autopct='%1.1f%%', startangle=90, counterclock=False)
plt.show()

# %%
# 파이차트
labels = ('A', 'B', 'C') 
xs = [50, 30, 40] 

patches, texts, autotexts = plt.pie(
    labels=labels, 
    labeldistance=1.1,   # label과 파이의 간격, 1일 경우 딱 붙음. 
    x = xs,              # 값
    explode=(0.1, 0.1, 0), # 파이조각 돌출 크기 (0 이면 돌출되지 않음)
    startangle=90,       # 그려지는 파이 조각 시작위치. 90은 12시 방향 
    shadow=False,        # 파이차트 그림자 효과 유무
    counterclock=False,  # 파이차트가 그려질 방향 (시계방향, 반시계 방향) 
    autopct='%1.1f%%',   # 파이조각 위에 표시될 글자 형태 (파이조각 전체대비 백분율)
    pctdistance=0.7,     # 백분률 표시 위치 (radius 기준으로 위치 선정)
    colors=['grey', 'red', 'blue'],  # 각 파이조각 컬러
)

# %% [markdown]
# #### Matplotlib 연습 02-3
#
# 교통사고 지역 지도 시각화

# %%
df = pd.read_csv(drive_path + 'Traffic_Accident_2017.csv', encoding='euc-kr')

# %% [markdown]
# folium 지도라이브러리 설치
#
# https://python-visualization.github.io/folium/

# %%
# 설치시, 코랩은 설치가 되어있어서 따로 설치할 필요 없음
# !pip install folium

# %% [markdown]
# 지도 만들기

# %%
import folium

seoul_map = folium.Map(location=[37.55, 126.98], zoom_start=12, width='50%')
seoul_map

# %% [markdown]
# 지도 스타일 적용

# %%
folium.Map(location=[37.55, 126.98], zoom_start=12, tiles='Stamen Terrain')

# %%
folium.Map(location=[37.55, 126.98], zoom_start=12, tiles='Stamen Toner')

# %% [markdown]
# 지도에 마커 표시

# %%
df[ ['경도', '위도'] ].head()
# Out:
#            경도         위도
# 0  126.768634  35.294464
# 1  127.133107  37.498741
# 2  126.566631  36.580069
# 3  127.069759  36.778505
# 4  126.898094  37.472946

# %%
s = df[df['발생지시도'] =='서울'][ ['발생년월일시', '위도', '경도'] ]
s.head()
# Out:
#         발생년월일시         위도          경도
# 1   2017010102  37.498741  127.133107
# 4   2017010104  37.472946  126.898094
# 12  2017010204  37.619097  126.915444
# 16  2017010208  37.487492  126.897739
# 20  2017010217  37.443959  126.903492

# %%
m = folium.Marker([37.498741, 127.133107], popup='hello')
m.add_to(seoul_map)
seoul_map

# %%
a = [1,2,3]
b = ['일', '이', '삼']
for a, b in zip(a, b) :
    print(a,b)
# Out:
# 1 일
# 2 이
# 3 삼

# %% [markdown]
# 원형 마커

# %% [markdown]
# 지도를 HTML 파일로 저장

# %%
seoul_map.save(drive_path + 'seoul.html')

# %% [markdown]
# #### 교통사고 추가정보 링크

# %% [markdown]
# 경찰청 공공데이터(교통사고정보)
#
# > https://www.data.go.kr/tcs/eds/selectCoreDataView.do?coreDataInsttCode=B552061&coreDataSn=1
#
# TAAS 교통사고분석시스템
#
# > http://taas.koroad.or.kr/sta/acs/gus/selectPopltnTfcacdSido.do?menuId=WEB_KMP_OVT_MVT_TAC_PTA

# %% [markdown]
# ## Matplotlib 요약

# %%
fig = plt.figure() 

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
ax4 = fig.add_subplot(2, 2, 4)

# %%
import numpy as np

ax1.clear()
ax1.hist( np.random.randn(200), bins =20, color='k' )

ax2.clear()
ax2.scatter( np.random.randn(30), np.arange(30))

ax3.clear()
ax3.scatter( np.arange(30), np.arange(30) + 3 * np.random.randn(30))

ax4.clear()
ax4.plot( np.arange(10), np.random.randn(10) )

fig

# %%
# 서브 플롯이 2행 3열 짜리가 만들어짐
fig, axes = plt.subplots(2,3)
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f07cb1e2590>,
# ...
#       dtype=object)

# %% [markdown]
# #### subplot 주변의 공간 고정

# %%
# subplot 간의 간격을 조정하는 함수 _adjust()
plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# ### subplot 주석달기 및 그리는 방법

# %%
fig, axes = plt.subplots(2, 1)
axes[0].text(0.4, 0.5, 'hello', family='monospace', fontsize=16)

arr = np.arange(10), np.random.randn(10)
axes[1].plot( arr[0], arr[1] )

anno_data = [
            (arr[0][1], arr[1][1], '1'),
            (arr[0][4], arr[1][4], '4'),
            (arr[0][7], arr[1][7], '7')
]

for x, y, label in anno_data :
    axes[1].annotate(label, xy =(x, y))

arr[1]
# Out:
# array([-0.46785071,  1.40313181,  0.25079521, -1.06917828,  1.12592098,
#        -1.00792545, -0.16599176,  0.28885014,  2.17382635, -0.34208039])

# %% [markdown]
# Matplotlib 다양한 도형 삽입하기
#
# https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.axes.Axes.add_patch.html

# %%
# 저장하기
fig.savefig('figpath.svg') # 백터이미지로 저장
fig.savefig('figpath.pdf') # pdf 파일로 저장
fig.savefig('figpath.png', dpi = 300, bbox_inches='tight') # dpi 해상도, bbox -> 화면에 꽉차게
# dpi : 인치당 도트 해상도
# bbox_inches : 실제 figure 둘레의 공백을 잘라낸다

# %%
from PIL import Image

img = Image.open('figpath.png')
# display( img )

plt.imshow( img )
plt.show()

# %% [markdown]
# ## Pandas 내장 그래프 도구
#
# - Pandas는 Matplotlib 라이브러리의 기능 일부를 내장
# - 별도의 임포트를 하지 않고 간단한 그래프 가능

# %%
fig, axes = plt.subplots(2, 1)
df = pd.Series( np.random.rand(16) )
df.plot(kind = 'bar', ax=axes[0], alpha=0.5) # alpha = 겹쳐서 그려야할때 투명도 조절
df.plot(kind = 'barh', ax=axes[1]) # barh는 가로로

# %% [markdown]
# Pandas 내장 plot() 메소드 그래프 종류
#
# |kind 옵션| 설명 |
# |---|---|
# |line| 선 그래프|
# |bar| 수직 막대 그래프|
# |barh| 수평 막대 그래프|
# |his| 히스토그램|
# |box| 박스 플롯|
# |kde| 커널 밀도 그래프|
# |area| 면적 그래프|
# |pie| 파이 그래프|
# |scatter| 산점도 그래프|
# |hexbin| 고밀도 산점도 그래프|

# %% [markdown]
# ### 선 그래프
#  DataFrame 객체.plot()
#
#  - 시간의 흐름에 따른 변화 추이를 보기 위해 사용

# %% [markdown]
# 발전전력량
#
# https://kosis.kr/statHtml/statHtml.do?orgId=101&tblId=DT_1ZGA74&conn_path=I2

# %%
import pandas as pd

df = pd.read_excel(drive_path + '남북한발전전력량.xlsx')
df.head()
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# 2  2658  2802  3196  3343  3430  3581  3427  3402  3523
# 3  1510  1478  1486  1547  1503  1388  1564  1648  1620
# 4     -     -     -     -    86   118   151   173   195
#
# [5 rows x 29 columns]

# %%
df[df['전력량 (억㎾h)'] == '남한']
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
#
# [1 rows x 29 columns]

# %%
# 남북한 발전 전력량 합계 비교 선그래프
df_ns = df.iloc[ [0, 5], 2: ]
df_ns.index = ['South', 'North']
df_ns.T.plot()

# %% [markdown]
# ### 막대 그래프
#
# DataFrame 객체.plot(kind='bar')
#
# - 선 그래프와 비슷하게 변화 추이를 보기 위해 사용

# %%
df_ns.T.plot(kind='bar')

# %% [markdown]
# ### 히스토그램
#
# DataFrame 객체.plot(kind='hist')
#
# - 연속된 자료의 분포를 보기 위해 사용

# %%
df_ns.T.plot(kind ='hist')

# %% [markdown]
# ### 산점도
#
# DataFrame 객체.plot(kind='scatter')
#
# - 두 변수의 관계를 보기 위해 사용

# %%
# df_ns.plot(kind ='scatter')

# %%
import pandas as pd
columns =  ['mpg','cylinders','displacement','horsepower','weight',
              'acceleration','model year','origin','name']
df = pd.read_csv(drive_path + 'auto-mpg.csv', header = None)
df.columns = columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    float64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# ### 박스 플롯
#
# DataFrame 객체.plot(kind='scatter')
#
# - 특정 변수의 데이터 분포와 분산 정도를 보기 위해 사용
# - 각 변수들의 데이터가 퍼져 있는 정도를 확인하기 위해

# %%
# 열(연비,실린더)을 선택하여 박스 플롯 그리기

# %% [markdown]
# ## Seaborn 시각화

# %%
import seaborn as sns

df = sns.load_dataset('mpg')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df['mpg'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: mpg, Length: 129, dtype: int64

# %%
df[ df['mpg'] > 45 ]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year origin       name
# 322          80  japan  mazda glc

# %%
df.plot(kind='scatter', x='model year', y='mpg')

# %% [markdown]
# ### 박스 플롯
#
# DataFrame 객체.plot(kind='scatter')
#
# - 특정 변수의 데이터 분포와 분산 정도를 보기 위해 사용
# - 각 변수들의 데이터가 퍼져 있는 정도를 확인하기 위해

# %%
df[['mpg']].plot(kind='box')

# %%
# 열(연비,실린더)을 선택하여 박스 플롯 그리기
df[['mpg', 'cylinders']].plot(kind='box')

# %% [markdown]
# ## Seaborn 시각화

# %%
import seaborn as sns

df = sns.load_dataset('mpg')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
# 히스토그램
df['mpg'].plot(kind = 'hist')
sns.displot(df['mpg'], bins=10)
sns.displot(df['mpg'], bins=20)
sns.displot(df['mpg'], bins=50, kde=True, color='g')

# %%
# Hex
sns.jointplot(kind = 'hex', data=df, x='weight', y='mpg')

# %%
# kde
sns.jointplot(kind = 'kde', data=df, x='weight', y='mpg')

# %%
# box
# sns.boxplot(data=df, x='mpg')
sns.boxplot(data=df, y='mpg')

# %%
# 실린더의 갯수마다 연비
sns.boxplot(data=df, y='mpg', x='cylinders')

# %%
sns.boxplot(data=df, y='mpg', x='origin')

# %%
# 바이올린 - 중간에 흰 점이 중간 값
sns.violinplot(data=df, y='mpg', x='origin')

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 산점도 행렬
sns.pairplot(data=df)

# %%
sns.pairplot(data=df, hue='species')

# %%
# heatmap
sns.heatmap( df.corr() )
plt.show()
